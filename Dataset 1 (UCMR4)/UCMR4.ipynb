# %%
import pandas as pd
import seaborn as sns

# %%
ucmr3 = pd.read_csv('/Users/minh-thytyler/Desktop/2023-24/capstone/data/finished datasets/GA_ucmr3.csv')
ucmr4 = pd.read_csv('/Users/minh-thytyler/Desktop/2023-24/capstone/data/finished datasets/GA_ucmr_4.csv')

# %%
ucmr3_name = pd.read_csv('/Users/minh-thytyler/Desktop/2023-24/capstone/data/finished datasets/ucmr3_name.csv')
ucmr4_name = pd.read_csv('/Users/minh-thytyler/Desktop/2023-24/capstone/data/finished datasets/ucmr4_name.csv')

# %%
ucmr4
# Out:
#           PWSID                         PWSName Size  FacilityID  \
# 0     GA0630000  Clayton County Water Authority    L         574
# 1     GA0630000  Clayton County Water Authority    L         574
# 2     GA0630000  Clayton County Water Authority    L         574
# 3     GA0630000  Clayton County Water Authority    L         574
# 4     GA0630000  Clayton County Water Authority    L         574
# ...         ...                             ...  ...         ...
# 1631  GA2470000              Rockdale Co. Water    L       14034
# 1632  GA2470000              Rockdale Co. Water    L       14034
# 1633  GA2470000              Rockdale Co. Water    L       14034
# 1634  GA2470000              Rockdale Co. Water    L       14034
# 1635  GA2470000              Rockdale Co. Water    L       14034
#
#                      FacilityName FacilityWaterType  SamplePointID  \
# 0     William Hooper Filter Plant                SW            301
# 1     William Hooper Filter Plant                SW            301
# 2     William Hooper Filter Plant                SW            301
# 3     William Hooper Filter Plant                SW            301
# 4     William Hooper Filter Plant                SW            301
# ...                           ...               ...            ...
# 1631          Distribution System                SW            508
# 1632          Distribution System                SW            508
# 1633          Distribution System                SW            508
# 1634          Distribution System                SW            508
# 1635          Distribution System                SW            508
#
#            SamplePointName SamplePointType  AssociatedFacilityID  ...    MRL  \
# 0       Finished Water Tap              EP                   NaN  ...  0.020
# 1       Finished Water Tap              EP                   NaN  ...  0.030
# 2       Finished Water Tap              EP                   NaN  ...  0.007
# 3       Finished Water Tap              EP                   NaN  ...  0.030
# 4       Finished Water Tap              EP                   NaN  ...  0.070
# ...                    ...             ...                   ...  ...    ...
# 1631  Union CH/E. Fairview              DS                   NaN  ...    NaN
# 1632  Union CH/E. Fairview              DS                   NaN  ...    NaN
# 1633  Union CH/E. Fairview              DS                   NaN  ...    NaN
# 1634  Union CH/E. Fairview              DS                   NaN  ...    NaN
# 1635  Union CH/E. Fairview              DS                   NaN  ...    NaN
#
#      Units   MethodID AnalyticalResultsSign  AnalyticalResultValue  \
# 0     �g/L    EPA 530                     <                    NaN
# 1     �g/L    EPA 530                     <                    NaN
# 2     �g/L    EPA 530                     <                    NaN
# 3     �g/L  EPA 525.3                     <                    NaN
# 4     �g/L  EPA 525.3                     <                    NaN
# ...    ...        ...                   ...                    ...
# 1631  �g/L  EPA 552.3                     =                 14.400
# 1632  �g/L  EPA 552.3                     =                 22.063
# 1633  �g/L  EPA 552.3                     =                  7.422
# 1634  �g/L  EPA 552.3                     =                 25.632
# 1635  �g/L  EPA 552.3                     =                 18.574
#
#      SampleEventCode MonitoringRequirement Region  State UCMR1SampleType
# 0               SEA1                    AM      4     GA             NaN
# 1               SEA1                    AM      4     GA             NaN
# 2               SEA1                    AM      4     GA             NaN
# 3               SEA1                    AM      4     GA             NaN
# 4               SEA1                    AM      4     GA             NaN
# ...              ...                   ...    ...    ...             ...
# 1631            SEH3                    AM      4     GA             NaN
# 1632            SEH3                    AM      4     GA             NaN
# 1633            SEH4                    AM      4     GA             NaN
# 1634            SEH4                    AM      4     GA             NaN
# 1635            SEH4                    AM      4     GA             NaN
#
# [1636 rows x 24 columns]

# %%
ucmr4_name
# Out:
#                          Contaminant CAS Registry Number  EPA Method  \
# 0                          germanium          7440-56-4       200.8
# 1                          manganese          7439-96-5       200.8
# 2        alpha-hexachlorocyclohexane           319-84-6       525.3
# 3                       chlorpyrifos          2921-88-2       525.3
# 4                         dimethipin         55290-64-7       525.3
# 5                           ethoprop         13194-48-4       525.3
# 6                        oxyfluorfen         42874-03-3       525.3
# 7                         profenofos         41198-08-7       525.3
# 8                       tebuconazole        107534-96-3       525.3
# 9   total permethrin (cis- & trans-)         52645-53-1       525.3
# 10                          tribufos            78-48-8       525.3
# 11          butylated hydroxyanisole         25013-16-5         530
# 12                       o-toluidine            95-53-4         530
# 13                         quinoline            91-22-5         530
# 14                         1-butanol            71-36-3         541
# 15                  2-methoxyethanol           109-86-4         541
# 16                     2-propen-1-ol           107-18-6         541
# 17              “total microcystins”                 NA         546
# 18                    microcystin-LA         96180-79-9         544
# 19                    microcystin-LF        154037-70-4         544
# 20                    microcystin-LR        101043-37-2         544
# 21                    microcystin-LY        123304-10-9         544
# 22                    microcystin-RR        111755-37-4         544
# 23                    microcystin-YR        101064-48-6         544
# 24                       nodularin-R        118399-22-7         544
# 25                        anatoxin-a         64285-06-9         545
# 26                cylindrospermopsin        143545-90-8         545
# 27                              HAA5                 NA   552.3/557
# 28                            HAA6Br                 NA   552.3/557
# 29                              HAA9                 NA   552.3/557
#
#        Contaminant Classification
# 0                           Metal
# 1                           Metal
# 2                       Pesticide
# 3                       Pesticide
# 4                       Pesticide
# 5                       Pesticide
# 6                       Pesticide
# 7                       Pesticide
# 8                       Pesticide
# 9                       Pesticide
# 10                      Pesticide
# 11  Semivolatile organic compound
# 12  Semivolatile organic compound
# 13  Semivolatile organic compound
# 14                        Alcohol
# 15                        Alcohol
# 16                        Alcohol
# 17                     Cyanotoxin
# 18                     Cyanotoxin
# 19                     Cyanotoxin
# 20                     Cyanotoxin
# 21                     Cyanotoxin
# 22                     Cyanotoxin
# 23                     Cyanotoxin
# 24                     Cyanotoxin
# 25                     Cyanotoxin
# 26                     Cyanotoxin
# 27        Disinfection Byproducts
# 28        Disinfection Byproducts
# 29        Disinfection Byproducts

# %%
#merging two datasets 

# Merge datasets based on 'Contaminant' column
#ucmr3_m= pd.merge(ucmr3, ucmr3_name, on='Contaminant', how='left')

# Fill missing values in 'Method Name' column with corresponding method names
#ucmr3_m['Method Name'] = ucmr3_m['Method Name'].fillna(method='ffill')

ucmr3_m = pd.merge(ucmr3, ucmr3_name[["Contaminant","Method Name"]], on = "Contaminant", how = "left")
ucmr4_m = pd.merge(ucmr4, ucmr4_name[["Contaminant","Contaminant Classification"]], on = "Contaminant", how = "left")

# %%
#filtering data
ucmr4_m = ucmr4_m.loc[ucmr4_m['PWSName'].isin(['Henry County Water & Sewer Authority', 'DeKalb County', 'Clayton County Water Authority'])]

# %%
#ucmr4_m.to_csv('/Users/minh-thytyler/Desktop/2023-24/capstone/data/finished datasets/ucmr4_m.csv', index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming ucmr4_m is your DataFrame containing the data

# Replace zeros with NaN in 'AnalyticalResultValue' column
ucmr4_m['AnalyticalResultValue'] = ucmr4_m['AnalyticalResultValue'].replace(0, np.nan)

# Convert 'CollectionDate' column to datetime format
ucmr4_m['CollectionDate'] = pd.to_datetime(ucmr4_m['CollectionDate'])

# Filter data where 'Contaminant Classification' is 'Pesticide'
disinfection_data = ucmr4_m[ucmr4_m['Contaminant Classification'] == 'Disinfection Byproducts']

# Group pesticide data by 'CollectionDate' and 'PWSName', calculate average 'AnalyticalResultValue'
grouped_df = disinfection_data.groupby(['CollectionDate', 'PWSName'])['AnalyticalResultValue'].mean().reset_index()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Loop through each PWSName and plot with a different color
for pws_name, color in zip(grouped_df['PWSName'].unique(), ['blue', 'green', 'red']):
    pws_data = grouped_df[grouped_df['PWSName'] == pws_name]
    ax.plot(pws_data['CollectionDate'], pws_data['AnalyticalResultValue'], marker='o', linestyle='-', color=color, label=pws_name)

# Set labels and title
ax.set_xlabel('Collection Date')
ax.set_ylabel('Average Analytical Result Value (µg/L)')
ax.set_title('Average Analytical Result Value (Disinfection Byproducts) by Collection Date and PWS Name')
ax.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plotz
plt.tight_layout()
plt.show()

# %%
# Filter data where 'Contaminant Classification' is 'Pesticide'
metal_data = ucmr4_m[ucmr4_m['Contaminant Classification'] == 'Metal']

# Group pesticide data by 'CollectionDate' and 'PWSName', calculate average 'AnalyticalResultValue'
grouped_df = metal_data.groupby(['CollectionDate', 'PWSName'])['AnalyticalResultValue'].mean().reset_index()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Loop through each PWSName and plot with a different color
for pws_name, color in zip(grouped_df['PWSName'].unique(), ['blue', 'green', 'red','yellow']):
    pws_data = grouped_df[grouped_df['PWSName'] == pws_name]
    ax.plot(pws_data['CollectionDate'], pws_data['AnalyticalResultValue'], marker='o', linestyle='-', color=color, label=pws_name)

# Set labels and title
ax.set_xlabel('Collection Date')
ax.set_ylabel('Average Analytical Result Value (µg/L)')
ax.set_title('Average Analytical Result Value (Metal) by Collection Date and PWS Name')
ax.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plotz
plt.tight_layout()
plt.show()
